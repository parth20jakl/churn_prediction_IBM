# %% [markdown]
# # Customer Churn Analysis
# Run the reproducible workflow from the project root: `python -m src.train_models`. Results are written to `outputs/`.

# %%
from src.data_preprocessing import load_data, clean_data, engineer_features
data = engineer_features(clean_data(load_data()))
data.shape, data['Churn'].value_counts(normalize=True)
